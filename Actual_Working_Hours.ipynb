# %% [markdown]
# ### Combined Compensation Data

# %%
import pandas as pd

df_comp = pd.DataFrame({
    'Staff First Name': ['John', 'Alice', 'Bob', 'Buelna', 'Buelna', 'Buelna', 'Buelna'],
    'Staff Last Name': ['Doe', 'Smith', 'Lee', 'Stepha', 'Stepha', 'Stepha', 'Stepha'],
    'Location ID': ['LOC1', 'LOC1', 'LOC2', 'DMC', 'DMC', 'DMC', 'DMC'],
    'Schedule Task Name': [
        'Task A', 'Task B', 'Task C',
        'DMC CRNA OB24', 'DMC CRNA OB24', 'DMC CRNA OB24', 'DMC CRNA OB24'
    ],
    'Schedule Start Date': pd.to_datetime([
        '2024-06-03', '2024-06-03', '2024-06-04',
        '2025-05-17', '2025-05-19', '2025-05-21', '2025-05-23'
    ]),
    'Schedule Start Time': ['08:00', '09:00', '10:00', '07:00', '07:00', '07:00', '07:00'],
    'Schedule End Date': pd.to_datetime([
        '2024-06-03', '2024-06-03', '2024-06-04',
        '2025-05-18', '2025-05-20', '2025-05-22', '2025-05-24'
    ]),
    'Schedule End Time': ['16:00', '13:00', '18:00', '07:00', '07:00', '07:00', '07:00'],
    'Schedule Duration (hours)': [8.0, 4.0, 8.0, 24.0, 24.0, 24.0, 24.0],
    'Pay Code ID': ['Bonus', 'Bonus', 'Bonus', 'Callback', 'Callback', 'Callback', 'Callback']
})


# Date conversions
df_comp['Schedule Start Date'] = pd.to_datetime(df_comp['Schedule Start Date'])
df_comp['Schedule End Date'] = pd.to_datetime(df_comp['Schedule End Date'])
display(df_comp)
# Out:
#   Staff First Name Staff Last Name Location ID Schedule Task Name  \
# 0             John             Doe        LOC1             Task A
# 1            Alice           Smith        LOC1             Task B
# 2              Bob             Lee        LOC2             Task C
# 3           Buelna          Stepha         DMC      DMC CRNA OB24
# 4           Buelna          Stepha         DMC      DMC CRNA OB24
# 5           Buelna          Stepha         DMC      DMC CRNA OB24
# 6           Buelna          Stepha         DMC      DMC CRNA OB24
#
#   Schedule Start Date Schedule Start Time Schedule End Date Schedule End Time  \
# 0          2024-06-03               08:00        2024-06-03             16:00
# 1          2024-06-03               09:00        2024-06-03             13:00
# 2          2024-06-04               10:00        2024-06-04             18:00
# 3          2025-05-17               07:00        2025-05-18             07:00
# ...

# %% [markdown]
# ### MCR data

# %%
df_mcr = pd.DataFrame({
    'DOS': pd.to_datetime([
        '2024-06-03', '2024-06-03', '2024-06-03',  # John Doe (3 cases)
        '2024-06-03',                             # Alice Smith
        '2024-06-04',                             # Bob Lee
        '2025-05-20', '2025-05-20', '2025-05-20', '2025-05-20'  # Stepha Buelna OB24 shifts
    ]),
    'FACILITY': ['LOC1', 'LOC1', 'LOC1', 'LOC1', 'LOC2', 'DMC', 'DMC', 'DMC', 'DMC'],
    'PROVIDER': [
        'John Doe', 'John Doe', 'Alice Smith', 'John Doe', 'Bob Lee',
        'Buelna Stepha', 'Buelna Stepha', 'Buelna Stepha', 'Buelna Stepha'
    ],
    'PROVIDER 2': [None, 'Alice Smith', None, None, None, None, None, None, None],
    'PROVIDER TYPE': ['Surgeon'] * 9,
    'Surgeon': ['Yes'] * 9,
    'PATIENT': ['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', 'P9'],
    'START TIME': [
        '08:00', '10:00', '09:00', '14:00', '10:30',
        '00:55', '01:00', '00:55', '00:55'
    ],
    'END TIME': [
        '09:00', '11:00', '10:00', '16:00', '12:30',
        '06:27', '03:00', '06:27', '06:27'
    ],
    'CALCULATED TIME': [1.0, 1.0, 1.0, 2.0, 2.0, 5.3,  2.0,  5.3,  5.3],
    'FILE NAME': ['F1.pdf'] * 5 + ['VRA_05202025_C'] * 4,
    '# OF PAGES': [2] * 5 + [152] * 4,
    'NOTES': [''] * 9
})

df_mcr['DOS'] = pd.to_datetime(df_mcr['DOS'])
display(df_mcr)
# Out:
#          DOS FACILITY       PROVIDER   PROVIDER 2 PROVIDER TYPE Surgeon  \
# 0 2024-06-03     LOC1       John Doe         None       Surgeon     Yes
# 1 2024-06-03     LOC1       John Doe  Alice Smith       Surgeon     Yes
# 2 2024-06-03     LOC1    Alice Smith         None       Surgeon     Yes
# 3 2024-06-03     LOC1       John Doe         None       Surgeon     Yes
# 4 2024-06-04     LOC2        Bob Lee         None       Surgeon     Yes
# 5 2025-05-20      DMC  Buelna Stepha         None       Surgeon     Yes
# 6 2025-05-20      DMC  Buelna Stepha         None       Surgeon     Yes
# 7 2025-05-20      DMC  Buelna Stepha         None       Surgeon     Yes
# 8 2025-05-20      DMC  Buelna Stepha         None       Surgeon     Yes
#
#   PATIENT START TIME END TIME  CALCULATED TIME       FILE NAME  # OF PAGES  \
# 0      P1      08:00    09:00              1.0          F1.pdf           2
# 1      P2      10:00    11:00              1.0          F1.pdf           2
# ...

# %% [markdown]
# ### Inside Shift Data

# %%
import pandas as pd

# Step 1: Unpivot MCR data
df_mcr_long = pd.melt(
    df_mcr,
    id_vars=[
        'DOS', 'FACILITY', 'PATIENT', 'START TIME', 'END TIME', 'CALCULATED TIME',
        'FILE NAME', '# OF PAGES', 'NOTES', 'PROVIDER TYPE', 'Surgeon'
    ],
    value_vars=['PROVIDER', 'PROVIDER 2'],
    var_name='Provider Role',
    value_name='PROVIDER_NAME'
)

# Step 2: Filter valid providers and prepare Full Name
df_mcr_long = df_mcr_long[df_mcr_long['PROVIDER_NAME'].notna()]
df_mcr_long['PROVIDER_NAME'] = df_mcr_long['PROVIDER_NAME'].str.strip()
df_mcr_long = df_mcr_long[df_mcr_long['PROVIDER_NAME'] != '']
df_mcr_long = df_mcr_long[df_mcr_long['PROVIDER_NAME'].str.split().str.len() == 2]
df_mcr_long[['First Name', 'Last Name']] = df_mcr_long['PROVIDER_NAME'].str.split(' ', expand=True)
df_mcr_long['Full Name'] = df_mcr_long['First Name'].str.strip() + ' ' + df_mcr_long['Last Name'].str.strip()

# Step 3: Convert dates and times to datetime
df_mcr_long['FACILITY'] = df_mcr_long['FACILITY'].astype(str)
df_mcr_long['DOS'] = pd.to_datetime(df_mcr_long['DOS'])
df_mcr_long['Actual Start Time'] = pd.to_datetime(df_mcr_long['DOS'].astype(str) + ' ' + df_mcr_long['START TIME'])
df_mcr_long['Actual End Time'] = pd.to_datetime(df_mcr_long['DOS'].astype(str) + ' ' + df_mcr_long['END TIME'])
df_mcr_long['Actual Worked Hours'] = df_mcr_long['CALCULATED TIME']  # Assuming CALCULATED TIME is in hours


# Step 4: Prepare compensation data
df_comp['Location ID'] = df_comp['Location ID'].astype(str)
df_comp['Full Name'] = df_comp['Staff First Name'].str.strip() + ' ' + df_comp['Staff Last Name'].str.strip()
df_comp['Schedule Start DateTime'] = pd.to_datetime(df_comp['Schedule Start Date'].astype(str) + ' ' + df_comp['Schedule Start Time'])
df_comp['Schedule End DateTime'] = pd.to_datetime(df_comp['Schedule End Date'].astype(str) + ' ' + df_comp['Schedule End Time'])

# Step 5: Cross join and filter by facility + actual time falling in schedule range
df_cross = df_mcr_long.merge(
    df_comp,
    how='left',
    left_on=['Full Name', 'FACILITY'],
    right_on=['Full Name', 'Location ID']
)

df_filtered = df_cross[
    (df_cross['Actual Start Time'] >= df_cross['Schedule Start DateTime']) &
    (df_cross['Actual End Time'] <= df_cross['Schedule End DateTime'])
]

# Step 6: Final formatting
df_result = df_filtered.rename(columns={
    'Full Name_x': 'Full Name'
})[[
    'Full Name', 'FACILITY', 'DOS', 'PATIENT',
    'Actual Start Time', 'Actual End Time', 'Actual Worked Hours',
    'Schedule Task Name', 'Schedule Start Date', 'Schedule Start Time',
    'Schedule End Date', 'Schedule End Time', 'Schedule Duration (hours)',
    'Pay Code ID'
]]

# Step 7: Display result
display(df_result)
# Out:
#         Full Name FACILITY        DOS PATIENT   Actual Start Time  \
# 0        John Doe     LOC1 2024-06-03      P1 2024-06-03 08:00:00
# 1        John Doe     LOC1 2024-06-03      P2 2024-06-03 10:00:00
# 2     Alice Smith     LOC1 2024-06-03      P3 2024-06-03 09:00:00
# 3        John Doe     LOC1 2024-06-03      P4 2024-06-03 14:00:00
# 4         Bob Lee     LOC2 2024-06-04      P5 2024-06-04 10:30:00
# 6   Buelna Stepha      DMC 2025-05-20      P6 2025-05-20 00:55:00
# 10  Buelna Stepha      DMC 2025-05-20      P7 2025-05-20 01:00:00
# 14  Buelna Stepha      DMC 2025-05-20      P8 2025-05-20 00:55:00
# 18  Buelna Stepha      DMC 2025-05-20      P9 2025-05-20 00:55:00
# 21    Alice Smith     LOC1 2024-06-03      P2 2024-06-03 10:00:00
#
#        Actual End Time  Actual Worked Hours Schedule Task Name  \
# 0  2024-06-03 09:00:00                  1.0             Task A
# 1  2024-06-03 11:00:00                  1.0             Task A
# ...

# %% [markdown]
# ### Add hardcoded label for inside-shift work

# %%
df_result['Work Type'] = 'Callback'
df_result_Callback = df_result.sort_values(by=['Full Name', 'DOS', 'FACILITY']).reset_index(drop=True)
display(df_result_Callback)
# Out:
#        Full Name FACILITY        DOS PATIENT   Actual Start Time  \
# 0    Alice Smith     LOC1 2024-06-03      P3 2024-06-03 09:00:00
# 1    Alice Smith     LOC1 2024-06-03      P2 2024-06-03 10:00:00
# 2        Bob Lee     LOC2 2024-06-04      P5 2024-06-04 10:30:00
# 3  Buelna Stepha      DMC 2025-05-20      P6 2025-05-20 00:55:00
# 4  Buelna Stepha      DMC 2025-05-20      P7 2025-05-20 01:00:00
# 5  Buelna Stepha      DMC 2025-05-20      P8 2025-05-20 00:55:00
# 6  Buelna Stepha      DMC 2025-05-20      P9 2025-05-20 00:55:00
# 7       John Doe     LOC1 2024-06-03      P1 2024-06-03 08:00:00
# 8       John Doe     LOC1 2024-06-03      P2 2024-06-03 10:00:00
# 9       John Doe     LOC1 2024-06-03      P4 2024-06-03 14:00:00
#
#       Actual End Time  Actual Worked Hours Schedule Task Name  \
# 0 2024-06-03 10:00:00                  1.0             Task B
# 1 2024-06-03 11:00:00                  1.0             Task B
# ...

# %% [markdown]
# ### Discard rows where Pay Code ID is 'BONUS' (case-insensitive)

# %%
df_result_Callback = df_result_Callback[df_result_Callback['Pay Code ID'].str.upper() != 'BONUS'].reset_index(drop=True)
display(df_result_Callback)
# Out:
#        Full Name FACILITY        DOS PATIENT   Actual Start Time  \
# 0  Buelna Stepha      DMC 2025-05-20      P6 2025-05-20 00:55:00
# 1  Buelna Stepha      DMC 2025-05-20      P7 2025-05-20 01:00:00
# 2  Buelna Stepha      DMC 2025-05-20      P8 2025-05-20 00:55:00
# 3  Buelna Stepha      DMC 2025-05-20      P9 2025-05-20 00:55:00
#
#       Actual End Time  Actual Worked Hours Schedule Task Name  \
# 0 2025-05-20 06:27:00                  5.3      DMC CRNA OB24
# 1 2025-05-20 03:00:00                  2.0      DMC CRNA OB24
# 2 2025-05-20 06:27:00                  5.3      DMC CRNA OB24
# 3 2025-05-20 06:27:00                  5.3      DMC CRNA OB24
#
#   Schedule Start Date Schedule Start Time Schedule End Date Schedule End Time  \
# 0          2025-05-19               07:00        2025-05-20             07:00
# 1          2025-05-19               07:00        2025-05-20             07:00
# 2          2025-05-19               07:00        2025-05-20             07:00
# ...

# %% [markdown]
# ### Outside Shift Data

# %%
# Merge again to prepare for identifying outside shift records
df_cross_all = df_mcr_long.merge(
    df_comp,
    how='left',
    left_on=['Full Name', 'FACILITY'],
    right_on=['Full Name', 'Location ID']
)

# Create actual datetime for shift windows
df_cross_all['Schedule Start DateTime'] = pd.to_datetime(df_cross_all['Schedule Start Date'].astype(str) + ' ' + df_cross_all['Schedule Start Time'])
df_cross_all['Schedule End DateTime'] = pd.to_datetime(df_cross_all['Schedule End Date'].astype(str) + ' ' + df_cross_all['Schedule End Time'])

# Filter only the records **outside** the scheduled shift
df_outside_shift = df_cross_all[
    (df_cross_all['Actual Start Time'] < df_cross_all['Schedule Start DateTime']) |
    (df_cross_all['Actual End Time'] > df_cross_all['Schedule End DateTime'])
]

# Finalize outside shift records (Overtime)
df_overtime = df_outside_shift.rename(columns={'Full Name_x': 'Full Name'})[[ 
    'Full Name', 'FACILITY', 'DOS', 'PATIENT',
    'Actual Start Time', 'Actual End Time', 'Actual Worked Hours',
    'Schedule Task Name', 'Schedule Start Date', 'Schedule Start Time',
    'Schedule End Date', 'Schedule End Time', 'Schedule Duration (hours)', 'Pay Code ID'
]].copy()

# Display only overtime records
display(df_overtime)
# Out:
#         Full Name FACILITY        DOS PATIENT   Actual Start Time  \
# 5   Buelna Stepha      DMC 2025-05-20      P6 2025-05-20 00:55:00
# 7   Buelna Stepha      DMC 2025-05-20      P6 2025-05-20 00:55:00
# 8   Buelna Stepha      DMC 2025-05-20      P6 2025-05-20 00:55:00
# 9   Buelna Stepha      DMC 2025-05-20      P7 2025-05-20 01:00:00
# 11  Buelna Stepha      DMC 2025-05-20      P7 2025-05-20 01:00:00
# 12  Buelna Stepha      DMC 2025-05-20      P7 2025-05-20 01:00:00
# 13  Buelna Stepha      DMC 2025-05-20      P8 2025-05-20 00:55:00
# 15  Buelna Stepha      DMC 2025-05-20      P8 2025-05-20 00:55:00
# 16  Buelna Stepha      DMC 2025-05-20      P8 2025-05-20 00:55:00
# 17  Buelna Stepha      DMC 2025-05-20      P9 2025-05-20 00:55:00
# 19  Buelna Stepha      DMC 2025-05-20      P9 2025-05-20 00:55:00
# 20  Buelna Stepha      DMC 2025-05-20      P9 2025-05-20 00:55:00
#
#        Actual End Time  Actual Worked Hours Schedule Task Name  \
# ...

# %% [markdown]
# ### Add hardcoded label for inside-shift work

# %%
df_overtime['Work Type'] = 'Overtime'  # Label
display(df_overtime)
# Out:
#         Full Name FACILITY        DOS PATIENT   Actual Start Time  \
# 5   Buelna Stepha      DMC 2025-05-20      P6 2025-05-20 00:55:00
# 7   Buelna Stepha      DMC 2025-05-20      P6 2025-05-20 00:55:00
# 8   Buelna Stepha      DMC 2025-05-20      P6 2025-05-20 00:55:00
# 9   Buelna Stepha      DMC 2025-05-20      P7 2025-05-20 01:00:00
# 11  Buelna Stepha      DMC 2025-05-20      P7 2025-05-20 01:00:00
# 12  Buelna Stepha      DMC 2025-05-20      P7 2025-05-20 01:00:00
# 13  Buelna Stepha      DMC 2025-05-20      P8 2025-05-20 00:55:00
# 15  Buelna Stepha      DMC 2025-05-20      P8 2025-05-20 00:55:00
# 16  Buelna Stepha      DMC 2025-05-20      P8 2025-05-20 00:55:00
# 17  Buelna Stepha      DMC 2025-05-20      P9 2025-05-20 00:55:00
# 19  Buelna Stepha      DMC 2025-05-20      P9 2025-05-20 00:55:00
# 20  Buelna Stepha      DMC 2025-05-20      P9 2025-05-20 00:55:00
#
#        Actual End Time  Actual Worked Hours Schedule Task Name  \
# ...

# %% [markdown]
# ### Union Both DataFrames

# %%
# Ensure both dataframes have the same columns and order
common_columns = [
    'Full Name', 'FACILITY', 'DOS', 'PATIENT',
    'Actual Start Time', 'Actual End Time', 'Actual Worked Hours',
    'Schedule Task Name', 'Schedule Start Date', 'Schedule Start Time',
    'Schedule End Date', 'Schedule End Time', 'Schedule Duration (hours)',
    'Pay Code ID', 'Work Type'
]

# Combine using concat
df_final_union = pd.concat([df_result_Callback[common_columns], df_overtime[common_columns]], ignore_index=True)

# Optional: sort by staff and date
df_final_union = df_final_union.sort_values(by=['Full Name', 'DOS', 'FACILITY']).reset_index(drop=True)

# Display final result
display(df_final_union)
# Out:
#         Full Name FACILITY        DOS PATIENT   Actual Start Time  \
# 0   Buelna Stepha      DMC 2025-05-20      P6 2025-05-20 00:55:00
# 1   Buelna Stepha      DMC 2025-05-20      P7 2025-05-20 01:00:00
# 2   Buelna Stepha      DMC 2025-05-20      P8 2025-05-20 00:55:00
# 3   Buelna Stepha      DMC 2025-05-20      P9 2025-05-20 00:55:00
# 4   Buelna Stepha      DMC 2025-05-20      P6 2025-05-20 00:55:00
# 5   Buelna Stepha      DMC 2025-05-20      P6 2025-05-20 00:55:00
# 6   Buelna Stepha      DMC 2025-05-20      P6 2025-05-20 00:55:00
# 7   Buelna Stepha      DMC 2025-05-20      P7 2025-05-20 01:00:00
# 8   Buelna Stepha      DMC 2025-05-20      P7 2025-05-20 01:00:00
# 9   Buelna Stepha      DMC 2025-05-20      P7 2025-05-20 01:00:00
# 10  Buelna Stepha      DMC 2025-05-20      P8 2025-05-20 00:55:00
# 11  Buelna Stepha      DMC 2025-05-20      P8 2025-05-20 00:55:00
# 12  Buelna Stepha      DMC 2025-05-20      P8 2025-05-20 00:55:00
# ...
